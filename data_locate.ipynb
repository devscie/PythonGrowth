# %% [markdown]
# ## Localização de Dados
#
# ### Armazenando dados em variáveis e explorando a localização
#
# Neste projeto vamos usar variáveis para registrar pontos de dados (referências) sobre a localização de um viajante como parte de um aplicativo de registro, diário de bordo.
#
# ### Tópicos do projeto:
#
# * Definindo variáveis
# * Solicitação de input do usuário no terminal
# * Imprimir latitude e longitude do usuário

# %%
country = "USA"
state = "Florida"
city = "Miami"
continent = "North America"

# %%
pip install geopy Nominatim
# Out:
# ...
#   Created wheel for Nominatim: filename=nominatim-0.1-cp37-none-any.whl size=2363 sha256=6414d0a10d73ee4c209cc4337ecbf476d21b5b33be96a6e850c0bc9799d00177
#   Stored in directory: /root/.cache/pip/wheels/d5/66/ed/e7476981dc30210b6b5ce7c25b054e8db35d44fdd2198003d4
# Successfully built Nominatim
# ...

# %%
from geopy.geocoders import Nominatim

city = input("Digite o nome da cidade: ")

address = city
geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
print(location.address)
print((location.latitude, location.longitude))
# Out:
# Digite o nome da cidade: New York
# New York, United States
# (40.7127281, -74.0060152)

# %%
from  geopy.geocoders import Nominatim

# geopy.geocoders.options.default_user_agent = "my-application"

geolocator = Nominatim(user_agent="my-application")
city ="New York"
country ="United States"
loc = geolocator.geocode(city+','+ country)
print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
# Out:
# latitude is :- 40.7127281
# longtitude is:- -74.0060152
